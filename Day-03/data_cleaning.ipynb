# %% [markdown]
# # Read CSV

# %%
import pandas as pd

csv_1=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv")
csv_1
# Out:
#     product_id                      title  \
# 0     17352320                      ether
# 1     17403950             Mast & Harbour
# 2     17404018             Mast & Harbour
# 3     22143924                Urbano Plus
# 4     14619398                    ScoldMe
# 5      8901821               UNDER ARMOUR
# 6       919032                   Roadster
# 7     18817326             Tommy Hilfiger
# 8      8426447                      WROGN
# 9     20355284                   Roadster
# 10    18818696             Tommy Hilfiger
# 11     9213113                   Roadster
# 12    13511732                       Puma
# 13    13591994                      Camey
# 14    21439050                      Kappa
# 15    13615634            U.S. Polo Assn.
# 16    13620624                   Roadster
# 17    13502414                       Puma
# 18    13621134                   Roadster
# 19    17686030          Allen Solly Tribe
# 20    13616400             Arrow New York
# ...

# %% [markdown]
# - operation on rows
# - select specific rows

# %%
csv_2=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",nrows=2)
# csv_2

print(type(csv_2))
# Out:
# <class 'pandas.DataFrame'>

# %% [markdown]
# #### Use Columns

# %%
# csv_3=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",usecols=["title","rating"])
csv_3=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",usecols=[0,3])
csv_3
# Out:
#     product_id  rating
# 0     17352320     4.4
# 1     17403950     4.2
# 2     17404018     3.9
# 3     22143924     3.2
# 4     14619398     0.0
# 5      8901821     4.3
# 6       919032     3.8
# 7     18817326     4.4
# 8      8426447     4.2
# 9     20355284     4.2
# 10    18818696     4.4
# 11     9213113     4.1
# 12    13511732     4.4
# 13    13591994     3.5
# 14    21439050     3.2
# 15    13615634     4.5
# 16    13620624     4.0
# 17    13502414     4.3
# 18    13621134     4.1
# 19    17686030     4.3
# 20    13616400     4.8
# 21    13480864     4.2
# 22    13622338     4.4
# 23    16295686     3.9
# 24    16298856     0.0
# 25    16277914     4.9
# 26    16292318     4.2
# 27    19201678     4.1
# 28    16923916     4.8
# 29    10143909     3.7
# 30    20085320     4.8
# 31    10555034     0.0
# 32    12987894     4.4
# 33    12953958     4.4
# 34    22629260     4.4
# 35    19291812     4.8
# 36    19206288     4.2
# 37    19264534     4.0
# 38    19264536     3.8

# %% [markdown]
# #### Skip Rows

# %%
csv_4=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",skiprows=[0,2,4])
csv_4
# Out:
#     17352320                      ether  \
# 0   17404018             Mast & Harbour
# 1   14619398                    ScoldMe
# 2    8901821               UNDER ARMOUR
# 3     919032                   Roadster
# 4   18817326             Tommy Hilfiger
# 5    8426447                      WROGN
# 6   20355284                   Roadster
# 7   18818696             Tommy Hilfiger
# 8    9213113                   Roadster
# 9   13511732                       Puma
# 10  13591994                      Camey
# 11  21439050                      Kappa
# 12  13615634            U.S. Polo Assn.
# 13  13620624                   Roadster
# 14  13502414                       Puma
# 15  13621134                   Roadster
# 16  17686030          Allen Solly Tribe
# 17  13616400             Arrow New York
# 18  13480864                Aeropostale
# 19  13622338                   Roadster
# 20  16295686               Miss & Chief
# 21  16298856                   Friskers
# ...

# %% [markdown]
# ### Make index to any soecific cols

# %%
csv_5=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",index_col="product_id")
csv_5
# Out:
#                                 title  \
# product_id
# 17352320                        ether
# 17403950               Mast & Harbour
# 17404018               Mast & Harbour
# 22143924                  Urbano Plus
# 14619398                      ScoldMe
# 8901821                  UNDER ARMOUR
# 919032                       Roadster
# 18817326               Tommy Hilfiger
# 8426447                         WROGN
# 20355284                     Roadster
# 18818696               Tommy Hilfiger
# 9213113                      Roadster
# 13511732                         Puma
# 13591994                        Camey
# 21439050                        Kappa
# 13615634              U.S. Polo Assn.
# 13620624                     Roadster
# 13502414                         Puma
# 13621134                     Roadster
# 17686030            Allen Solly Tribe
# 13616400               Arrow New York
# 13480864                  Aeropostale
# 13622338                     Roadster
# ...

# %% [markdown]
# #### Make header of Another Row

# %%
csv_6=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",header=1)
# csv_6

# %% [markdown]
# #### Add Any header with name

# %%
csv_7=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",names=["cols1","cols2","cols3","cols4","cols5","cols6","cols7","cols8"])
# csv_7

# %% [markdown]
# #### Make Column And rename It

# %%
csv_8 = pd.read_csv(
    "D:\\Celebal Technology learning\\Day-03\\tshirts.csv",
    header=None
)

csv_8.columns = [f"col{i}" for i in range(csv_8.shape[1])]

# csv_8

# %% [markdown]
# #### Change Data Type

# %%
# csv_9=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",nrows=2)
# csv_9=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",dtype={"initial_price":"float"})
csv_9=pd.read_csv("D:\\Celebal Technology learning\\Day-03\\tshirts.csv",dtype={"ratings_count":"float"})
# csv_9

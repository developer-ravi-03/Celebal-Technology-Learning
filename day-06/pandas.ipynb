# %% [markdown]
# ### Introdunction to pandas

# %%
print("Introduction to Pandas")
# Out:
# Introduction to Pandas

# %% [markdown]
# ### Key Data Structures in Pandas
# * series
# * Dataframes

# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df=pd.DataFrame({"names":["Ravi","Harry","Shubham"],"marks":[100,65,76]})

# %%
df
# Out:
#      names  marks
# 0     Ravi    100
# 1    Harry     65
# 2  Shubham     76

# %%
df=pd.read_csv("D:\\Celebal Technology learning\\Day-06\\tshirts.csv")
df
# Out:
#     product_id                      title  \
# 0     17352320                      ether
# 1     17403950             Mast & Harbour
# 2     17404018             Mast & Harbour
# 3     22143924                Urbano Plus
# 4     14619398                    ScoldMe
# 5      8901821               UNDER ARMOUR
# 6       919032                   Roadster
# 7     18817326             Tommy Hilfiger
# 8      8426447                      WROGN
# 9     20355284                   Roadster
# 10    18818696             Tommy Hilfiger
# 11     9213113                   Roadster
# 12    13511732                       Puma
# 13    13591994                      Camey
# 14    21439050                      Kappa
# 15    13615634            U.S. Polo Assn.
# 16    13620624                   Roadster
# 17    13502414                       Puma
# 18    13621134                   Roadster
# 19    17686030          Allen Solly Tribe
# 20    13616400             Arrow New York
# ...

# %%
df.head()
# Out:
#    product_id           title  \
# 0    17352320           ether
# 1    17403950  Mast & Harbour
# 2    17404018  Mast & Harbour
# 3    22143924     Urbano Plus
# 4    14619398         ScoldMe
#
#                                  product_description  rating  ratings_count  \
# 0  Kora Collection Blue Sustainable Naturally Dye...     4.4             70
# 1          Men Mint Green Typography Printed T-shirt     4.2            200
# 2       Men Blue & White Striped Regular Fit T-shirt     3.9             72
# 3             Size Typography Printed Cotton T-shirt     3.2              6
# 4     Women Multicoloured Pack Of 2 Slim Fit T-shirt     0.0              0
#
#    initial_price  discount  final_price currency  \
# 0         1099.0      47.0  "₹1,099.00"      INR
# 1          899.0       NaN    "₹899.00"      INR
# 2          999.0       NaN    "₹999.00"      INR
# 3         1099.0      45.0  "₹1,099.00"      INR
# 4         1598.0      55.0    "₹719.00"      INR
#
# ...

# %%
df.tail()
# Out:
#     product_id           title  \
# 34    22629260             max
# 35    19291812  Mad Over Print
# 36    19206288        FERANOID
# 37    19264534  Flying Machine
# 38    19264536  Flying Machine
#
#                                   product_description  rating  ratings_count  \
# 34          Striped Polo Collar Short Sleeves T-shirt     4.4              7
# 35             Women Black Love Wins Oversize T-shirt     4.8              5
# 36          Men Purple Henley Neck Bio Finish T-shirt     4.2             21
# 37  Men Black & White Printed Pure Cotton Slim Fit...     4.0            102
# 38  Men Rust Orange Melange Pure Cotton Slim Fit T...     3.8             60
#
#     initial_price  discount final_price currency  \
# 34          799.0      40.0   "₹479.00"      INR
# 35         1599.0      58.0   "₹671.00"      INR
# 36         1199.0      50.0   "₹599.00"      INR
# 37          999.0      61.0   "₹389.00"      INR
# 38         1299.0      61.0   "₹506.00"      INR
#
# ...

# %%
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price   discount
# count  3.900000e+01  39.000000      39.000000      39.000000  32.000000
# mean   1.547068e+07   3.876923     120.897436    1478.358974  52.312500
# std    4.391180e+06   1.198346     206.471075     788.897548  14.510147
# min    9.190320e+05   0.000000       0.000000     599.000000  25.000000
# 25%    1.350707e+07   3.900000       8.000000     999.000000  40.000000
# 50%    1.629232e+07   4.200000      54.000000    1299.000000  53.000000
# 75%    1.901019e+07   4.400000     102.500000    1632.000000  60.250000
# max    2.262926e+07   4.900000     994.000000    3999.000000  80.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              39 non-null     int64
#  1   title                   39 non-null     str
#  2   product_description     39 non-null     str
#  3   rating                  39 non-null     float64
#  4   ratings_count           39 non-null     int64
#  5   initial_price           39 non-null     float64
#  6   discount                32 non-null     float64
#  7   final_price             39 non-null     str
#  8   currency                39 non-null     str
#  9   images                  39 non-null     str
#  10  delivery_options        39 non-null     str
#  11  product_details         39 non-null     str
#  12  breadcrumbs             39 non-null     str
#  13  product_specifications  39 non-null     str
#  14  amount_of_stars         39 non-null     str
# ...

# %% [markdown]
# ### Data Selection

# %%
type(df["title"])
# Out:
# pandas.Series

# %%
df["title"]
# Out:
# 0                         ether
# 1                Mast & Harbour
# 2                Mast & Harbour
# 3                   Urbano Plus
# 4                       ScoldMe
# 5                  UNDER ARMOUR
# 6                      Roadster
# 7                Tommy Hilfiger
# 8                         WROGN
# 9                      Roadster
# 10               Tommy Hilfiger
# 11                     Roadster
# 12                         Puma
# 13                        Camey
# 14                        Kappa
# 15              U.S. Polo Assn.
# 16                     Roadster
# 17                         Puma
# 18                     Roadster
# 19            Allen Solly Tribe
# 20               Arrow New York
# 21                  Aeropostale
# 22                     Roadster
# 23                 Miss & Chief
# 24                     Friskers
# 25                         Parx
# 26                     Bewakoof
# 27                Tokyo Talkies
# 28                  Monte Carlo
# ...

# %%
df[["title", "ratings_count"]]
# Out:
#                         title  ratings_count
# 0                       ether             70
# 1              Mast & Harbour            200
# 2              Mast & Harbour             72
# 3                 Urbano Plus              6
# 4                     ScoldMe              0
# 5                UNDER ARMOUR             64
# 6                    Roadster            641
# 7              Tommy Hilfiger             58
# 8                       WROGN            514
# 9                    Roadster             74
# 10             Tommy Hilfiger             58
# 11                   Roadster            994
# 12                       Puma            167
# 13                      Camey              2
# 14                      Kappa              9
# 15            U.S. Polo Assn.             69
# 16                   Roadster            154
# 17                       Puma            327
# 18                   Roadster            312
# 19          Allen Solly Tribe             23
# ...

# %%
type(df.iloc[0])
# Out:
# pandas.Series
